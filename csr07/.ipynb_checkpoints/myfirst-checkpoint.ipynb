# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pi = 3.14159
x = np.linspace(0,2*pi)
y = np.sin(x)
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">
